# %%
from serpapi import search

params = {
  "engine": "google",
  "q": "white rabbit pokhara",
  "api_key": "bb77e86b06518259bfd30bab508bd54b4279db24576b18d09d19eece62c81461"
}

searchqq = search(params)

# %%
for i in searchqq['organic_results']:
    if "tripadvisor.com" in i["link"]:
        link = i['link']
        break

print(link)
# Out:
# https://www.tripadvisor.com/Restaurant_Review-g293891-d10556984-Reviews-White_Rabbit_Coffee-Pokhara_Gandaki_Zone_Western_Region.html

# %% [markdown]
# ---
# ---

# %%
from serpapi import search

params = {
  "engine": "google_maps",
  "q": "white rabbit pokhara",
  "api_key": "bb77e86b06518259bfd30bab508bd54b4279db24576b18d09d19eece62c81461"
}

search_rev = search(params)

# %%
data_id=search_rev["place_results"]['data_id']

# %%
from serpapi import search

params = {
  "engine": "google_maps_reviews",
  "data_id": data_id,
  "api_key": "bb77e86b06518259bfd30bab508bd54b4279db24576b18d09d19eece62c81461",
  "num":20
}

search_reviews = search(params)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File p:\my-great-food-buddie\.venv\Lib\site-packages\serpapi\http.py:59, in raise_for_status(r)
#      58 try:
# ---> 59     r.raise_for_status()
#      60 except requests.exceptions.HTTPError as e:
#
# File p:\my-great-food-buddie\.venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://serpapi.com/search?engine=google_maps_reviews&data_id=0x3995951ef3fe215f%3A0x316ee9634cc49838&api_key=bb77e86b06518259bfd30bab508bd54b4279db24576b18d09d19eece62c81461&num=20
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ...

# %%
counter =0
for i in search_reviews['reviews']:
    review = i['extracted_snippet']['original']
    counter=+1
    print(review)
    

print(len(search_reviews['reviews']))
# Out:
# Great coffee shop to stop by after a trek. The food is amazing - We ordered a cappuccino, a blueberry smoothie, French fries, pancake stack and french toast. They were all 10/10. The waitress was very polite, quick, and helpful. The atmosphere was good, as we sat on the balcony watching people passing by. I would highly recommend this place!
# The breakfast here is tasty, affordable, and comes with a view of the lake. Service is attentive. The WR special big breakfast was sumptuous and felt like a complete meal. Coffee was great and perfectly accompanied our meal. Would go back again!
# ...

# %%
searchqq
# Out:
# {
#     "search_metadata": {
#         "id": "682371394de49a6870eb423a",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/691f31781d266c61/682371394de49a6870eb423a.json",
#         "created_at": "2025-05-13 16:20:09 UTC",
#         "processed_at": "2025-05-13 16:20:09 UTC",
#         "google_url": "https://www.google.com/search?q=white+rabbit+pokhara&oq=white+rabbit+pokhara&sourceid=chrome&ie=UTF-8",
#         "raw_html_file": "https://serpapi.com/searches/691f31781d266c61/682371394de49a6870eb423a.html",
#         "total_time_taken": 2.03
#     },
#     "search_parameters": {
#         "engine": "google",
#         "q": "white rabbit pokhara",
#         "google_domain": "google.com",
#         "device": "desktop"
#     },
#     "search_information": {
#         "query_displayed": "white rabbit pokhara",
#         "total_results": 234000,
#         "time_taken_displayed": 0.3,
#         "organic_results_state": "Results for exact spelling"
# ...

# %%
from serpapi import search

params = {
  "engine": "google_maps_reviews",
  "place_id": "ChIJXyH-8x6VlTkROJjETGPpbjE",
  "api_key": "bb77e86b06518259bfd30bab508bd54b4279db24576b18d09d19eece62c81461"
}

search_reviews111 = search(params)

# %%
search_reviews111
# Out:
# {
#     "search_metadata": {
#         "id": "6823815955ba65a981251be3",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/b1bae66b5cdeee34/6823815955ba65a981251be3.json",
#         "created_at": "2025-05-13 17:28:57 UTC",
#         "processed_at": "2025-05-13 17:28:57 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s0x3995951ef3fe215f:0x316ee9634cc49838!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/b1bae66b5cdeee34/6823815955ba65a981251be3.html",
#         "prettify_html_file": "https://serpapi.com/searches/b1bae66b5cdeee34/6823815955ba65a981251be3.prettify",
#         "total_time_taken": 1.24
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJXyH-8x6VlTkROJjETGPpbjE",
#         "hl": "en"
#     },
#     "place_info": {
#         "title": "White Rabbit Coffee",
# ...

# %%
counter =0
for i in search_reviews111['reviews']:
    review = i['extracted_snippet']['original']
    counter=+1
    print(review)
    

print(len(search_reviews111['reviews']))
# Out:
# Great coffee shop to stop by after a trek. The food is amazing - We ordered a cappuccino, a blueberry smoothie, French fries, pancake stack and french toast. They were all 10/10. The waitress was very polite, quick, and helpful. The atmosphere was good, as we sat on the balcony watching people passing by. I would highly recommend this place!
# The breakfast here is tasty, affordable, and comes with a view of the lake. Service is attentive. The WR special big breakfast was sumptuous and felt like a complete meal. Coffee was great and perfectly accompanied our meal. Would go back again!
# ...
